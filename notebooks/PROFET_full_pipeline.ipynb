# %% [markdown]
# ## Load and preprocess data
#
# Datasets are located in ```data``` directory. The trajectory will be visualized in 2D principal component axes.
#
#
# * ```Gene_Expression_Matrix.txt``` : Raw data matrix in $\mathbb{R}^{M \times N}$ is composed of $M$ rows for individual samples and $N$ columns of different genes.
#
# * ```Cells_days.txt``` : The entire dataset is divided into 4 classes which correspond to different days.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pk

from IPython.display import Image, display

import os
import sys

main_dir = os.getcwd()
if "notebooks" in main_dir:
    main_dir = main_dir[:-10]
    os.chdir(main_dir)
elif main_dir == "/content":
    main_dir = main_dir + "/GPA-source_code"
print(main_dir)
    
sys.path.append(main_dir)
data_dir = main_dir + '/data/'

# %%
## Read Cell Day Matrix (synthetic data)

df_cls = pd.read_table(data_dir + '/Synthetic data/' + 'Data_4_Cells_Days_matrix.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Cell Day Matrix (mESC data)


df_cls = pd.read_table(data_dir + '/mESC data/' + 'Data_0_Cells_Days_matrix.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Cell Day Matrix (EMT data)


df_cls = pd.read_table(data_dir + '/EMT data/' + 'EMT_Cells_Days_matrix.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Cell Day Matrix (MCF7 cell line data)

df_cls = pd.read_table(data_dir + '/MCF7 Cell Line/' + 'Cells_Days_basal_NDPR.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Cell Day Matrix (Patient PA3)


df_cls = pd.read_table(data_dir + '/Patient_PA3/' + 'Cells_Days_palbo_BMC_tumor.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Cell Day Matrix (Patient 862)


df_cls = pd.read_table(data_dir + '/Patient_862/' + 'cell_matrix_palbo_862_1.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Cell Day Matrix (Patient 887)


df_cls = pd.read_table(data_dir + '/Patient_887/' + 'cell_matrix_palbo_887_1.txt', sep="\t")
print(df_cls)

cls = set(df_cls['day'])
print("classes:", cls)
print()

N_samples_cls = {}
for c in cls:
    N_samples_cls[c] = len(df_cls[df_cls['day']==c])
    print("Day ", c, ": sample size: ", N_samples_cls[c])

# Save the DataFrame with the new file name "Cells_Days.txt"
output_path = data_dir + "Cells_Days.txt"
df_cls.to_csv(output_path, sep="\t", index=False)
print(f"File saved as: {output_path}")

# %%
## Read Gene expression matrix (Synthetic data)


# select genes from time series data
if os.path.exists(data_dir + '/Synthetic data/' +  "Data_4_gene_expression_matrix.txt"):
    df_reduced_emt = pd.read_table(data_dir  + '/Synthetic data/' + 'Data_4_gene_expression_matrix.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %%
## Read Gene expression matrix (mESC data)


# select genes from time series data
if os.path.exists(data_dir + '/mESC data/'+ "Data_0_gene_expression_matrix.txt"):
    df_reduced_emt = pd.read_table(data_dir + '/mESC data/' + 'Data_0_gene_expression_matrix.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %%
## Read Gene expression matrix (EMT Data)
# select genes from 72 genes
if os.path.exists(data_dir + '/EMT data/' + "submatrix_72_genes_expression_matrix.txt"):
    df_reduced_emt = pd.read_table(data_dir + '/EMT data/' + 'submatrix_72_genes_expression_matrix.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %%
## Read Gene expression matrix (MCF7 cell line data)

# select genes from time series data
if os.path.exists(data_dir + '/MCF7 Cell Line/' + "combined_matrix_transposed_basal_NDPR_Rgene.txt"):
    df_reduced_emt = pd.read_table(data_dir + '/MCF7 Cell Line/' + 'combined_matrix_transposed_basal_NDPR_Rgene.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %%
## Read Gene expression matrix (Patient PA3)

# select genes from time series data
if os.path.exists(data_dir + '/Patient_PA3/' + "combined_matrix_transposed_palbo_BMC_nofibroblast_malignant_Rgene.txt"):
    df_reduced_emt = pd.read_table(data_dir + '/Patient_PA3/' + 'combined_matrix_transposed_palbo_BMC_nofibroblast_malignant_Rgene.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %%
## Read Gene expression matrix (Patient 862)

# select genes from time series data
if os.path.exists(data_dir + '/Patient_862/' + "combined_matrix_transposed_palbo_NatMed_862_nofibroblast_malignant_Rgene.txt"):
    df_reduced_emt = pd.read_table(data_dir + '/Patient_862/' + 'combined_matrix_transposed_palbo_NatMed_862_nofibroblast_malignant_Rgene.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %%
## Read Gene expression matrix (Patient 887)

# select genes from time series data
if os.path.exists(data_dir + '/Patient_887/' + "combined_matrix_transposed_palbo_NatMed_887_nofibroblast_malignant_Rgene.txt"):
    df_reduced_emt = pd.read_table(data_dir + '/Patient_887/' + 'combined_matrix_transposed_palbo_NatMed_887_nofibroblast_malignant_Rgene.txt', sep="\t")
    print(df_reduced_emt)
    col_selection_emt = df_reduced_emt.columns[1:]
elif os.path.exists(data_dir + 'Gene_Expression_Matrix.txt'):
    col_selection_emt = np.loadtxt(data_dir + 'non_overlap_72_genes.txt', dtype=str)
    df_reduced_emt = df.filter(items=np.concatenate((['id'], col_selection_emt)))
    print(df_reduced_emt)
    print("%d EMT Hallmark genes are excluded!" % (len(col_selection_emt)-len(df_reduced_emt.columns[1:])))
    col_selection_emt = df_reduced_emt.columns[1:]
    df_reduced_emt.to_csv(data_dir + 'submatrix_72_genes_expression_matrix.txt', sep='\t', index=False)

  
print("Original space dimension = ", len(col_selection_emt))

# Get the list of gene names (excluding the first column which contains cell names)
gene_names = df_reduced_emt.columns[1:].tolist()

# Print the list of gene names
print(gene_names)

# %% [markdown]
# ## Dimensionality reduction by PCA
#
# PCA provides a *reconstruction map* and therefore we compare the reconstructed GPA-transported dataset with source and target in the original 15K dimensional space. <br>
# PCA is applied on entire days matrix with dimensions ```d_red = 2, 4, 8, 16, 30, 60```. <br>
#
#   * PCA projection maps ```pca = decomposition.PCA(n_components=d_red, random_state=0)``` will be stored at ```data/pca_{d_red}.pkl```
#   * Projected sample matrix (row: entire days samples, column: PCA vectors in principal order) will be stored at ```data/pca_projected.csv``` along with days information ```data/Cells_Days.txt```
#
#
# The point is to **project to a space where the gene expressions on different days are distinguishable**.
#
# Or apply different dimension reduction algorithm in the cell below.

# %%
from sklearn import decomposition

# %%
# Apply PCA to gene expression matrix with different dimensions (For mESC, EMT, MCF7, patients PA3, 862, 887 data)

d_reds = [2, 4, 8, 16, 30, 60]

if not os.path.exists(data_dir+"emt_pca_variance_ratios.png"):
    mat_reduced = np.array(df_reduced_emt)[:,1:] # exclude id

    for d_red in d_reds:
        pca = decomposition.PCA(n_components=d_red, random_state=0)
        pca.fit(mat_reduced)
        mat_projected = pca.transform(mat_reduced)
        # mat_reconstructed = pca.inverse_transform(mat_projected)

        # store pca map for each d_red
        pk.dump([pca,], open(data_dir+"emt_pca_"+str(d_red)+".pkl","wb"))

        if d_red == 60:
            # store projected matrix 
            np.savetxt(data_dir+"emt_pca_projected.csv", mat_projected, delimiter=",")

            # plot variance ratio
            variances = pca.explained_variance_ratio_ * 100
            #np.array(pca.explained_variance_)/np.sum(pca.explained_variance_)*100
            plt.plot(range(1, len(variances)+1), np.cumsum(variances), '-')
            plt.xlabel("number of PCA basis", fontsize=16)
            plt.ylabel("Explained variance (%)", fontsize=16)

            for reduced_dim in d_reds[:-1]:
                plt.vlines(x=reduced_dim, ymin=variances[0], ymax=np.sum(variances), color = 'r', linestyles='dashed')
                plt.text(x=reduced_dim+7, y= np.cumsum(variances)[reduced_dim-1]-3, s="$d'=%d$\n%.2f %%" % (reduced_dim, np.cumsum(variances)[reduced_dim-1]), fontsize=16)

            plt.ylim([variances[0], np.sum(variances)])
            plt.tick_params(axis='x', labelsize=14)
            plt.tick_params(axis='y', labelsize=14)
              
            plt.savefig(data_dir+"emt_pca_variance_ratios.png")
            plt.show() 
else:
    image = plt.imread(data_dir+"emt_pca_variance_ratios.png")
    plt.imshow(image)
    plt.axis('off') 
    plt.show()

# %%
# Apply PCA to gene expression matrix with different dimensions (for synthetic data)

d_reds = [2, 4, 8, 16, 26] ## For Synthetic data

if not os.path.exists(data_dir+"emt_pca_variance_ratios.png"):
    mat_reduced = np.array(df_reduced_emt)[:,1:] # exclude id

    for d_red in d_reds:
        pca = decomposition.PCA(n_components=d_red, random_state=0)
        pca.fit(mat_reduced)
        mat_projected = pca.transform(mat_reduced)
        # mat_reconstructed = pca.inverse_transform(mat_projected)

        # store pca map for each d_red
        pk.dump([pca,], open(data_dir+"emt_pca_"+str(d_red)+".pkl","wb"))

        if d_red == 26:
            # store projected matrix 
            np.savetxt(data_dir+"emt_pca_projected.csv", mat_projected, delimiter=",")

            # plot variance ratio
            variances = pca.explained_variance_ratio_ * 100
            #np.array(pca.explained_variance_)/np.sum(pca.explained_variance_)*100
            plt.plot(range(1, len(variances)+1), np.cumsum(variances), '-')
            plt.xlabel("number of PCA basis", fontsize=16)
            plt.ylabel("Explained variance (%)", fontsize=16)

            for reduced_dim in d_reds[:-1]:
                plt.vlines(x=reduced_dim, ymin=variances[0], ymax=np.sum(variances), color = 'r', linestyles='dashed')
                plt.text(x=reduced_dim+7, y= np.cumsum(variances)[reduced_dim-1]-3, s="$d'=%d$\n%.2f %%" % (reduced_dim, np.cumsum(variances)[reduced_dim-1]), fontsize=16)

            plt.ylim([variances[0], np.sum(variances)])
            plt.tick_params(axis='x', labelsize=14)
            plt.tick_params(axis='y', labelsize=14)
              
            plt.savefig(data_dir+"emt_pca_variance_ratios.png")
            plt.show() 
else:
    image = plt.imread(data_dir+"emt_pca_variance_ratios.png")
    plt.imshow(image)
    plt.axis('off') 
    plt.show()

# %% [markdown]
# ## Visualization of data using PCA

# %%
dim_red_method = 'EMT_PCA' # 'PCA' or 'EMT_PCA'

# %%
np.array(df_reduced_emt)[:,1:]

# %%
# load "original" matrix 
# PCA: only available in local notebook currently
if dim_red_method == 'EMT_PCA':
    mat = np.array(df_reduced_emt)[:,1:] # exclude id
elif dim_red_method == 'PCA':
    try:
        mat = np.array(df)[:,1:] # exclude id
    except:
        print(data_dir, "Gene_Expression_Matrix.txt is missing!")
    
try:
    mats = {}
    for c in cls:
        mats[c] = mat[df_cls['day']==c].astype(dtype=float)
except:
    print("mat variable is missing!")

# %%
reducer = decomposition.PCA(n_components=2, random_state=0)
reducer.fit(mat)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Assume cls and mats are defined somewhere in your code
# reducer = TSNE()  # Example reducer, adjust according to your actual reducer
# Define six contrasting colors
contrast_colors = [
    '#1f77b4',  # blue
    '#d62728',  # green
    '#ff7f0e',  # orange
    '#8c564b',  # brown
    '#d62728',  # red 
    '#9467bd'   # purple
]

# Transform all days
vis_all_days = reducer.transform(mat)
np.random.seed(125)

for i, day in enumerate(cls):
    vis_day = reducer.transform(mats[day])
    color = contrast_colors[i % len(contrast_colors)]  # Use the defined set of contrasting colors
    
    fig = plt.figure(figsize=(4, 3))
    plt.scatter(vis_all_days[:, 0], vis_all_days[:, 1], color='lightgray', alpha=0.3, s=0.7)
    plt.scatter(vis_day[:, 0], vis_day[:, 1], alpha=1.0, color=color, label=f'day{day}', s=0.7)
    plt.legend()
    plt.title(f'Day {day}')
    plt.show()

# %% [markdown]
# ## Transport source to target using GPA
# * Put ```--dataset Transport_genes -N_dim (d_red) --label (day1) (day2) --reduction (dim_red_method) --exp_no (exp_memo)``` and additional GPA training parameters that you want to temporarily change for this experiment.
# * Default GPA parameters and hyper-parameters are listed in ```configs/Transport_genes-GPA_NN.yaml```.
# * Recommended tunable parameters depending on examples are ```--epochs``` for number of transportation steps, ```--lr_P``` for time step size for the ODE, ```--epochs_phi``` for number of gradient ascent updates for $\phi$, ```--lr_phi``` gradient ascent stepsize for $\phi$.
# * For the loss function,
#     * the default setting is the Lipschitz regularized KL divergence in Donsker-Varadhan (DV) formulation; ```--f KL --formulation DV -L 1.0```
#     * But if KL divergence is not suitable for the loss, we can try another Lipschitz regularized $f$-divergence in Legendre transform (LT) formulation; <br> ex) ```--f alpha -alpha 2.0 --formulation LT -L 1.0```
# * Lipschitz constant $L$ is an algorithm level parameter. ```-L 1.0``` makes the algorithm stable in general.
# * `--` tag means required parameter, `-` tag means optional parameter defined in ```scripts/util/input_args.py```.
# * The results will be saved in ```assets/Transport_genes/```. Results include
#     * movie for the evolving particles in the designated 2 axes ```plot_axes``` and ```plot_axes_join```
#     * movie for the evolving vector field in the designated 2 axes ```plot_axes``` and ```plot_axes_join```
#     * trajectories of particles in time in pickle format.
#
# The video of resulting GPA trajectory in the latent space is stored in ```assets/Transport_genes/``` directory as gif format file.

# %%
# Wasserstein-2 distance
import torch # for W2 calculation purpose
try:
    from geomloss import SamplesLoss
except:
    # !pip3 install geomloss
    from geomloss import SamplesLoss

def W2(X, Y):
    X = torch.from_numpy(X).type(torch.float32)
    Y = torch.from_numpy(Y).type(torch.float32)

    return SamplesLoss(loss='sinkhorn', p=2)(X, Y).numpy()


# conversion from gpa iterations to algorithm time 
def calculate_time_steps(dt, iter_nos, physical_time=True):
    if physical_time == True:
        iter_nos_new = []
        if type(dt) == list: # decaying or varying dt
            for iter_no in iter_nos:
                if iter_no == 0:
                    iter_nos_new.append(0)
                else:
                    iter_nos_new.append(sum(dt[:iter_no]))
        else: # constant dt
            for iter_no in iter_nos:
                iter_nos_new.append(dt*iter_no)
        iter_nos = iter_nos_new
    return iter_nos


import matplotlib.animation as animation

# %%
# function to apply GPA
def run(source_t, target_t, intermediate_t = [], 
        total_iter = 10000, lr_P = 0.0025, termination_error = 0.01, termination_error_metric = 'KE',
        d_red=32, exp_memo = '2'):
    intermediate_t = np.array(intermediate_t)
    if len(intermediate_t) == 0:
        intermediate_t = range(source_t+1, target_t)
        
    # data parameters
    day1, day2 = source_t, target_t

    # GPA parameters
    f, alpha, L = 'KL', None, 1.0
    #f, alpha, L = 'alpha', 2.0, 1.0
    epochs = total_iter # for sample run
    #lr_P = 0.0025
    plot_axes = '0 1' # 2 axes for plotting in 2D
    plot_axes_join = '0_1'

    # --------
    N_source = N_samples_cls[day1]
    N_target = N_samples_cls[day2]

    result_dir = '%s/assets/Transport_genes/' % main_dir
    if f == 'KL':
        f_Lip = 'KL-Lipschitz_%.4f' % L
    else:
        f_Lip = 'alpha=%05.2f-Lipschitz_%.4f' % (alpha, L)
    result_name = f_Lip + '-%d_%dtimes-%s_dim%d_%04d_%04d_00_%s' % \
    (day1, day2, dim_red_method, d_red, N_target, N_source, exp_memo)
    print(result_name)
    result_filepath = result_dir + result_name + '.pickle'
    
    
    # run GPA
    if os.path.exists(result_filepath): # load existing result
       with open(result_filepath, "rb") as fr:
            param, result = pk.load(fr)
            X1_trpts = result['trajectories']
    else:  # run GPA
        if f == 'KL':
            # !python3 $main_dir/main.py --dataset Transport_genes -L $L --label $day1 $day2 \
            --reduction $dim_red_method -N_dim $d_red --exp_no $exp_memo --f $f \
            --formulation DV --epochs $epochs \
            -termination_error $termination_error -termination_error_metric $termination_error_metric\
            -plot_axes $plot_axes --lr_P $lr_P
        else:
            # !python3 $main_dir/main.py --dataset Transport_genes -L $L --label $day1 $day2 \
            --reduction $dim_red_method -N_dim $d_red --exp_no $exp_memo --f $f -alpha $alpha \
            --formulation LT --epochs $epochs \
            -termination_error $termination_error -termination_error_metric $termination_error_metric\
            -plot_axes $plot_axes --lr_P $lr_P
    
    
    #img_src = result_dir + result_name + '-%s-movie.gif' % plot_axes_join
    #display(Image(filename = img_src))

    
    # read the result
    with open(result_filepath, "rb") as fr:
        param, result = pk.load(fr)
        X1_trpts = result['trajectories']
        
    # epochs(=iteration counts) -> physical time
    ts = np.arange(1, len(result['trajectories'])*param['save_iter']+1, param['save_iter'])
    print("Number of epochs: ", len(result['trajectories'])*param['save_iter'], ", time step size: ", param['lr_P'])
    pts = param['lr_P'] * ts

    X1_trpt = X1_trpts[-1]
    
    # load PCA
    if dim_red_method == 'EMT_PCA':
        pca_filename = "emt_pca_%d.pkl" % d_red
    elif dim_red_method == 'PCA':
        pca_filename = "pca_%d.pkl" % d_red
    else:
        print("PCA mapping for the reduction method and dimension is not available")

    with open(data_dir + pca_filename,"rb") as fr:
        [pca] = pk.load(fr)
    
    
    contrast_colors = [
    '#1f77b4',  # blue
    '#2ca02c',  # green
    '#ff7f0e',  # orange
    '#8c564b',  # brown
    '#d62728',  # red 
    '#9467bd'  # purple (to be used for index 8)
    ]

    # Create a color mapping for the specific indices
    colors = {0: contrast_colors[0], 1: contrast_colors[1], 2: contrast_colors[2], 3: contrast_colors[3], 4: contrast_colors[4], 8: contrast_colors[5]}
        
    
    
    # Visualization in the original space 
    img_src = result_dir + result_name + '-movie-original.gif' 
    if os.path.exists(img_src): # try loading saved movie
        display(Image(filename = img_src))
    else: # draw, save and load
        fig, ax = plt.subplots()
        ims = []
        X1_vis = reducer.transform(mats[day1])
        X2_vis = reducer.transform(mats[day2])
        im = ax.scatter(X1_vis[:,0], X1_vis[:,1], color=colors[day1], 
                        alpha=1.0, s=0.7, zorder=10, label=f'day {day1}') # source in red
        ax.scatter(X2_vis[:,0], X2_vis[:,1], color=colors[day2], 
                   alpha=0.7, s=0.7, zorder=7, label=f'day {day2}') # target in blue
        for t in intermediate_t:
            X1_intermediate_vis = reducer.transform(mats[t])
            ax.scatter(X1_intermediate_vis[:,0], X1_intermediate_vis[:,1], color=colors[t], 
                        alpha=0.5, s=0.7, zorder=5, label=f'day {t}')
        ax.scatter(vis_all_days[:,0], vis_all_days[:,1], color='lightgray', 
                   alpha=0.3, s=0.7, zorder=1) # backgrounds in gray
        #leg = ax.legend(loc='upper right')
        ttl = ax.text(0.5,1.05, "t = %.3f" % 0.0, \
                      bbox={'facecolor':'w', 'alpha':0.5, 'pad':5}, \
                      transform=ax.transAxes, ha="center")
        ims.append([im, ttl])#, leg])
        for i, X1_trpt in enumerate(X1_trpts):  # trajectories
            if np.isnan(X1_trpt).any():
                break
            X1_hat = pca.inverse_transform(X1_trpt)
            X1_hat_vis = reducer.transform(X1_hat)
            im = ax.scatter(X1_hat_vis[:,0], X1_hat_vis[:,1], color=colors[day1], 
                            alpha=1.0, s=0.7, zorder=10, label=f'day {day1}') # transported source 
            ax.scatter(X2_vis[:,0], X2_vis[:,1], color=colors[day2], 
                       alpha=0.7, s=0.7, zorder=7, label=f'day {day2}') # target
            ax.scatter(X1_intermediate_vis[:,0], X1_intermediate_vis[:,1], color=colors[day1+1], 
                        alpha=0.5, s=0.7, zorder=5, label=f'day {day1+1}')
            ax.scatter(vis_all_days[:,0], vis_all_days[:,1], color='lightgray', 
                       alpha=0.3, s=0.7, zorder=1) # backgrounds in gray
            #leg = ax.legend(loc='upper right')
            ttl = ax.text(0.5,1.05, "t = %.3f" % pts[i], \
                          bbox={'facecolor':'w', 'alpha':0.5, 'pad':5}, \
                          transform=ax.transAxes, ha="center")
            ims.append([im, ttl])#, leg])
        ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=200)
        writergif = animation.PillowWriter(fps=3)
        ani.save(img_src, writer=writergif)
        plt.clf()
        display(Image(filename = img_src))

# %%
## Synthetic data (need to run two pieces with source_t, target_t = 0, 2 and source_t, target_t = 2, 4)

source_t, target_t = 0, 2
#source_t, target_t = 2, 4

run(source_t, target_t, intermediate_t = [], total_iter = 5000, lr_P = 0.04,
    termination_error = 1e-4, termination_error_metric = 'f_Lip', # termination_error_metric from ['f_Lip', 'KE']
    d_red=26, exp_memo='Data_4_T0_2_26d_lr_P_0.04_5000i_f_Lip_1e-4')

# %%
## mESC data (need to run two pieces with source_t, target_t = 0, 2 and source_t, target_t = 2, 4)

source_t, target_t = 0, 2
#source_t, target_t = 2, 4

run(source_t, target_t, intermediate_t = [], total_iter = 5000, lr_P = 0.0025,
    termination_error = 1e-4, termination_error_metric = 'f_Lip', # termination_error_metric from ['f_Lip', 'KE']
    d_red=2, exp_memo='Data_0_T0_2_2d_lr_P_0.0025_5000i_f_Lip_1e-4_test')

# %%
## EMT data

source_t, target_t = 0, 4
run(source_t, target_t, intermediate_t = [], total_iter = 10000, lr_P = 0.005,
    termination_error = 2e-5, termination_error_metric = 'f_Lip', # termination_error_metric from ['f_Lip', 'KE']
    d_red=8, exp_memo='Data_0_T0_4_8d_lr_P_0.005_10000i_f_Lip_1e-4')

# %%
## MCF7 cell line and patients (PA3 862 887) data

source_t, target_t = 0, 4
run(source_t, target_t, intermediate_t = [], total_iter = 5000, lr_P = 0.0025,
    termination_error = 2e-5, termination_error_metric = 'f_Lip', # termination_error_metric from ['f_Lip', 'KE']
    d_red=2, exp_memo='Palbo_887_nofibroblast_malignant_Rgene_T0_4_2d_lr_P_0.0025_5000i_f_Lip_2e-5')

# %% [markdown]
# ## Time-Dependent Vector Field (Force Matching)
#
# This section outlines how to train a time-dependent vector field using the outputs from GPA.
#
# ---
#
# ### **Step 1: Run GPA for Each Time Subinterval**
#
# For each subinterval of time, run the original GPA (as shown in the cell above). This step produces `.pickle` files containing the reconstructed trajectories.
#
# ---
#
# ### **Step 2: Train the Time-Dependent Vector Field**
#
# Use the script `train_time_dep_vectorfields.py` to train a time-dependent vector field based on the GPA outputs from Step 1.
#
# ---
#
# #### 🧪 Example 1: Two-Piece GPA (mESC Data)
#
# This example combines two consecutive GPA segments (from time 0 to 2, and from 2 to 4):
#
# python3 scripts/train_time_dep_vectorfields.py \
#     --dataset Transport_genes \
#     --ts 0 2 4 \
#     --files \
#         KL-Lipschitz_1.0000-0_2times-EMT_PCA_dim2_0093_0092_00_Data_0_T0_2_2d_lr_P_0.0025_5000i_f_Lip_1e-4.pickle \
#         KL-Lipschitz_1.0000-2_4times-EMT_PCA_dim2_0093_0093_00_Data_0_T2_4_2d_lr_P_0.0025_5000i_f_Lip_1e-4.pickle \
#     --hidden_units 64 64 64 \
#     --mini_batch_size_t 50 \
#     --exp_memo EMT_dim2-f_Lip=5e-2-t_size=50-network=64_64_64 \
#     --threshold_type f_Lip \
#     --threshold_val 5e-2 \
#     --lr_NN 0.00005 \
#     --iterations 100000
#
# #### 🧪 Example 1: Two-Piece GPA (mESC Data)
#
# python3 scripts/train_time_dep_vectorfields.py \
#     --dataset Transport_genes \
#     --ts 0 4 \
#     --files \
#         KL-Lipschitz_1.0000-0_2_4times-EMT_PCA_dim8_1147_2734_00_Data_0_T0_4_8d_lr_P_0.005_10000i_f_Lip_1e-4.pickle \
#     --hidden_units 64 64 64 \
#     --mini_batch_size_t 50 \
#     --exp_memo 72GS_dim8-f_Lip=5e-2-t_size=50-network=64_64_64 \
#     --threshold_type f_Lip \
#     --threshold_val 5e-2 \
#     --lr_NN 0.00005 \
#     --iterations 100000
#
# ### **Step 3: Evaluate sample trajectory by running below**

# %%
import tensorflow as tf
result_dir = '%s/assets/Transport_genes/' % main_dir

def load_W(filename):
    with open(filename, "rb") as fr:
        W, b, p = pk.load(fr)

    W = [tf.Variable(w,  dtype=tf.float32) for w in W]
    b = [tf.Variable(b_,  dtype=tf.float32) for b_ in b]

    return W, b, p

def v(x, t, W, b):   # neural newtork for time-dependent vectorfield
    num_layers = len(W)
    activation_ftn = tf.nn.tanh
        
    h = tf.concat([x, t*tf.ones([x.shape[0], 1], dtype=tf.float32)], axis=1)
    for l in range(0,num_layers-1):
        h = activation_ftn(tf.add(tf.matmul(h, W[l]), b[l]))
    out=tf.add(tf.matmul(h, W[-1]), b[-1])

    return out

def time_integration(x0, T, dt):
    x = tf.constant(x0, dtype=tf.float32)
    xs = [x0]
    for i in range(int(T/dt)):
        vv = v(x, dt*i, W, b)
        x += dt * vv
        xs.append(x.numpy())
    return xs


def generate_animation(days, intermediate_days, X1_trpts, dt, physical_dt, img_src, d_red = 2, vs = None):
    # load PCA
    if dim_red_method == 'EMT_PCA':
        pca_filename = "emt_pca_%d.pkl" % d_red
    elif dim_red_method == 'PCA':
        pca_filename = "pca_%d.pkl" % d_red
    else:
        print("PCA mapping for the reduction method and dimension is not available")

    with open(data_dir + pca_filename,"rb") as fr:
        [pca] = pk.load(fr)
    
    fig, ax = plt.subplots()
    ims = []

    contrast_colors = [
    '#1f77b4',  # blue
    '#2ca02c',  # green
    '#ff7f0e',  # orange
    '#8c564b',  # brown
    '#d62728',  # red 
    '#9467bd'  # purple (to be used for index 8)
    ]

    # Create a color mapping for the specific indices
    colors = {0: contrast_colors[0], 1: contrast_colors[1], 2: contrast_colors[2], 3: contrast_colors[3], 4: contrast_colors[4], 8: contrast_colors[5]}    
    
    
    for i, X1_trpt in enumerate(X1_trpts):  # trajectories
        if np.isnan(X1_trpt).any():
            break
        X1_trpt_vis = X1_trpt
        
        if type(vs) != type(None) and i < len(X1_trpts)-1:
            X1_trpt_vis_next = X1_trpts[i+1]
            vs_vis = (X1_trpt_vis_next-X1_trpt_vis) / dt
            im = ax.quiver(X1_trpt_vis[:, 0], X1_trpt_vis[:, 1], vs_vis[:, 0], vs_vis[:, 1], 
                           width=0.003, headwidth=7, headlength=15, headaxislength=7, zorder=15)                            
        else:
            im = ax.scatter(X1_trpt_vis[:,0], X1_trpt_vis[:,1], color=colors[days[0]], 
                            alpha=1.0, s=0.7, zorder=10, label=f'day {days[0]}') # transported source 
            for t in days[1:]:
                X2_vis = pca.transform(mats[t])
                ax.scatter(X2_vis[:,0], X2_vis[:,1], color=colors[t], 
                   alpha=1.0, s=0.7, zorder=5, label=f'day {t}') # target 
            
            for t in intermediate_days:
                X1_intermediate_vis = pca.transform(mats[t])
                ax.scatter(X1_intermediate_vis[:,0], X1_intermediate_vis[:,1], color='lightgray', 
                        alpha=0.3, s=0.7, zorder=1, label=f'day {t}')
        #ax.set_xlim([-5,6])
        #ax.set_ylim([-5,6])
        
        #leg = ax.legend(loc='upper right')
        ttl = ax.text(0.5,1.05, "t = %.3f" % (physical_dt*i), \
                      bbox={'facecolor':'w', 'alpha':0.5, 'pad':5}, \
                      transform=ax.transAxes, ha="center")
        ims.append([im, ttl])#, leg])
        
    ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True, repeat_delay=200)
    writergif = animation.PillowWriter(fps=3)
    ani.save(img_src, writer=writergif)
    plt.clf()
    display(Image(filename = img_src))

# %%
## PROFET for two pieces GPA (Synthetic data)

exp_name = 'f_Lip=5e-2-t_size=50-network=64_64_64_26d' #'times_10_particles_200_3'
d_red = 26
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0,2,4], [1,3], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0,2,4], [1,3], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")

# %%
## PROFET for two pieces GPA (mESC data)

exp_name = 'EMT_dim2-f_Lip=5e-2-t_size=50-network=64_64_64_test' #'times_10_particles_200_3'
d_red = 2
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0,2,4], [1,3], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0,2,4], [1,3], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")

# %%
## FROFET for one piece of GPA (EMT data)

exp_name = '72GS_dim8-f_Lip=5e-2-t_size=50-network=64_64_64' #'times_10_particles_200_3'
d_red = 8
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0, 2, 4], [], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0, 2, 4], [], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")

# %%
## FROFET for one piece of GPA (MCF7 cell ine data)

exp_name = 'Palbo_NDPR_nofibroblast_malignant_Rgene_dim2-f_Lip=5e-2-t_size=50-network=64_64_64' #'times_10_particles_200_3'
d_red = 2
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")

# %%
## FROFET for one piece of GPA (Patient PA3)

exp_name = 'Palbo_BMC_nofibroblast_malignant_Rgene_dim2-f_Lip=5e-2-t_size=50-network=64_64_64' #'times_10_particles_200_3'
d_red = 2
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")

# %%
## FROFET for one piece of GPA(Patient 862)

exp_name = 'Palbo_862_nofibroblast_malignant_Rgene_dim2-f_Lip=5e-2-t_size=50-network=64_64_64' #'times_10_particles_200_3'
d_red = 2
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")

# %%
## FROFET for one piece of GPA (Patient 887)

exp_name = 'Palbo_887_nofibroblast_malignant_Rgene_dim2-f_Lip=5e-2-t_size=50-network=64_64_64' #'times_10_particles_200_3'
d_red = 2
filename = result_dir + exp_name + ".pickle"
W, b, p = load_W(filename)

# load PCA
if dim_red_method == 'EMT_PCA':
    pca_filename = "emt_pca_%d.pkl" % d_red
elif dim_red_method == 'PCA':
    pca_filename = "pca_%d.pkl" % d_red
else:
    print("PCA mapping for the reduction method and dimension is not available")

with open(data_dir + pca_filename,"rb") as fr:
    [pca] = pk.load(fr)

dt = p['numerical_ts'][-1]/200
X1_trpts = time_integration(pca.transform(mats[0]), T = p['numerical_ts'][-1], dt = dt)

physical_dt = dt * p['ts'][-1] / p['numerical_ts'][-1]

img_src = result_dir + exp_name + '-movie-original.gif' 
img_src1 = result_dir + exp_name + '-movie-original-with-arrows.gif'
if os.path.exists(img_src): # try loading saved movie
    display(Image(filename = img_src))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src, d_red = d_red)
if os.path.exists(img_src1): # try loading saved movie
    display(Image(filename = img_src1))
else:
    generate_animation([0, 4], [], X1_trpts, dt, physical_dt, img_src1, d_red = d_red, vs = "vecotorfield")
